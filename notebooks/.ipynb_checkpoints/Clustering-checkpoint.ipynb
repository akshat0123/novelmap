# %% [markdown]
# # Clustering

# %% [markdown]
# ## Load Files

# %%
from goodreads_shelves import get_shelves_given_titles
from preprocessor import PreProcessor
from library import Library
from tqdm import tqdm
from os.path import isfile
import pickle

TITLES = '../data/base/books.txt'
SHELVES = '../data/base/book_shelves.json'

DELIM = '../data/base/books_delimiter_data.txt'
RAW = '../data/raw'

DICT = '../data/dumps/book_dictionary.dict'
CORP = '../data/dumps/book_corpus.dict'
TOKEN = '../data/dumps/token_dump.p'

LDA_MODEL = '../data/dumps/lda_model.p'
LSI_MODEL = '../data/dumps/lsi_model.p'

# %% [markdown]
# ## Baseline

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt
from sklearn.cluster import KMeans
import numpy as np
import json

baseline_book_vectors = json.load(open(SHELVES, 'r'))
baseline_book_vectors = {title: baseline_book_vectors[title] for title in baseline_book_vectors if len(baseline_book_vectors[title]) != 0}

vocab = []
for title in baseline_book_vectors:
    vocab += baseline_book_vectors[title]

vocab = enumerate(list(set(vocab)))
vocab_dict = { pair[1]: pair[0] for pair in vocab }

pca = PCA(n_components=2)

book_matrix = []
titles = []
for title in baseline_book_vectors:
    book_vector = np.zeros(len(vocab_dict)) 
    for word in baseline_book_vectors[title]:
        book_vector[vocab_dict[word]] += 1
    titles.append(title)
    book_matrix.append(book_vector)
    
book_matrix = np.array(book_matrix)
pca_books = np.array([book for book in pca.fit_transform(book_matrix)])

x, y = zip(*pca_books)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(pca_books, np.zeros(len(x)))
neighbors = [book for book in knn.kneighbors(pca_books, n_neighbors=5)[1]]

neighbor_names = {} 
for group in neighbors:
    neighbor_names[titles[group[0]]] = [titles[j] for j in group[1:]]
    
for title in neighbor_names:
    print(title, neighbor_names[title], '\n')

# fig, ax = plt.subplots(1, 1, figsize=(30, 30))
# 
# ax.scatter(x, y)
# for i in range(len(x)):
#     ax.annotate(titles[i], (x[i],y[i])) 
# 
# plt.show()
# Out:
# Adventures of Huckleberry Finn ['Ethan Frome', 'The Jungle', 'The Adventures of Tom Sawyer', 'The Call of the Wild']
#
# Alices Adventures in Wonderland ['Treasure Island', 'The Wonderful Wizard of Oz', 'Kidnapped', 'Captains Courageous']
#
# Anna Karenina ['The Count of Monte Cristo', 'The Brothers Karamazov', 'Les Miserables', 'Crime and Punishment']
#
# Anthem ['Gullivers Travels', 'Oliver Twist', 'The Three Musketeers', 'Tarzan of the Apes']
#
# A Tale of Two Cities ['Great Expectations', 'Les Miserables', 'The Count of Monte Cristo', 'Anna Karenina']
#
# Captains Courageous ['Kidnapped', 'Treasure Island', 'Tarzan of the Apes', 'The Merry Adventures of Robin Hood']
#
# Crime and Punishment ['The Count of Monte Cristo', 'The Brothers Karamazov', 'Anna Karenina', 'Moby Dick']
#
# Dracula ['Frankenstein', 'Dr Jekyll and Mr Hyde', 'The Picture of Dorian Gray', 'Sense and Sensibility']
#
# Dr Jekyll and Mr Hyde ['Dracula', 'The Adventures of Sherlock Holmes', 'The War of the Worlds', 'Phantom of the Opera']
#
# Ethan Frome ['The Jungle', 'The Scarlett Letter', 'Moby Dick', 'Adventures of Huckleberry Finn']
#
# Frankenstein ['The Picture of Dorian Gray', 'Sense and Sensibility', 'Dracula', 'Pride and Prejudice']
#
# Great Expectations ['A Tale of Two Cities', 'Les Miserables', 'The Count of Monte Cristo', 'Anna Karenina']
#
# Gullivers Travels ['Anthem', 'Oliver Twist', 'Tarzan of the Apes', 'The Three Musketeers']
#
# Heart of Darkness ['The Three Musketeers', 'Oliver Twist', 'Pride and Prejudice', 'Great Expectations']
#
# Kidnapped ['Captains Courageous', 'Treasure Island', 'Tarzan of the Apes', 'The Merry Adventures of Robin Hood']
#
# Les Miserables ['A Tale of Two Cities', 'The Count of Monte Cristo', 'Anna Karenina', 'Great Expectations']
#
# Moby Dick ['Crime and Punishment', 'The Scarlett Letter', 'Ethan Frome', 'The Jungle']
#
# Oliver Twist ['Phantom of the Opera', 'Heart of Darkness', 'The Three Musketeers', 'Pride and Prejudice']
#
# Phantom of the Opera ['Oliver Twist', 'Pride and Prejudice', 'Sense and Sensibility', 'Dracula']
#
# Pride and Prejudice ['Sense and Sensibility', 'The Picture of Dorian Gray', 'Heart of Darkness', 'Frankenstein']
#
# Sense and Sensibility ['Pride and Prejudice', 'The Picture of Dorian Gray', 'Frankenstein', 'Wuthering Heights']
#
# Tarzan of the Apes ['Captains Courageous', 'Kidnapped', 'Treasure Island', 'The Merry Adventures of Robin Hood']
#
# The Adventures of Sherlock Holmes ['The War of the Worlds', 'Dr Jekyll and Mr Hyde', 'The Time Machine', 'Phantom of the Opera']
#
# The Adventures of Tom Sawyer ['The Call of the Wild', 'White Fang', 'Adventures of Huckleberry Finn', 'The Merry Adventures of Robin Hood']
#
# The Brothers Karamazov ['Anna Karenina', 'The Count of Monte Cristo', 'War and Peace', 'Crime and Punishment']
#
# The Call of the Wild ['The Adventures of Tom Sawyer', 'White Fang', 'Adventures of Huckleberry Finn', 'The Merry Adventures of Robin Hood']
#
# The Count of Monte Cristo ['Anna Karenina', 'The Brothers Karamazov', 'Les Miserables', 'Crime and Punishment']
#
# The Jungle ['The Scarlett Letter', 'Ethan Frome', 'Moby Dick', 'Adventures of Huckleberry Finn']
#
# The Merry Adventures of Robin Hood ['Treasure Island', 'Kidnapped', 'Captains Courageous', 'Tarzan of the Apes']
#
# The Picture of Dorian Gray ['Frankenstein', 'Sense and Sensibility', 'Pride and Prejudice', 'Wuthering Heights']
#
# The Scarlett Letter ['The Jungle', 'Ethan Frome', 'Moby Dick', 'Crime and Punishment']
#
# The Three Musketeers ['Heart of Darkness', 'Oliver Twist', 'Great Expectations', 'A Tale of Two Cities']
#
# The Time Machine ['The War of the Worlds', 'The Adventures of Sherlock Holmes', 'Dr Jekyll and Mr Hyde', 'Dracula']
#
# The War of the Worlds ['The Adventures of Sherlock Holmes', 'The Time Machine', 'Dr Jekyll and Mr Hyde', 'Dracula']
#
# The Wonderful Wizard of Oz ['The Merry Adventures of Robin Hood', 'Treasure Island', 'Kidnapped', 'Alices Adventures in Wonderland']
#
# Treasure Island ['Kidnapped', 'Captains Courageous', 'The Merry Adventures of Robin Hood', 'Tarzan of the Apes']
#
# War and Peace ['The Brothers Karamazov', 'Anna Karenina', 'The Count of Monte Cristo', 'Crime and Punishment']
#
# White Fang ['The Adventures of Tom Sawyer', 'The Call of the Wild', 'The Merry Adventures of Robin Hood', 'Adventures of Huckleberry Finn']
#
# Wuthering Heights ['The Picture of Dorian Gray', 'Pride and Prejudice', 'Sense and Sensibility', 'Great Expectations']

# %% [markdown]
# ## LDA

# %%
# Get book texts split into chapters
preprocessor = PreProcessor(DICT, CORP, DELIM, RAW, TOKEN, 0)
dictionary, corpus, books = preprocessor.get_library_info()

if not isfile(LDA_MODEL):
    lda = Library(dictionary, corpus, num_topics = 50, chunksize=10, model_type = 'LDA')
    for title in tqdm(books):
        lda.add_book(books[title])

    pickle.dump(lda, open(LDA_MODEL, 'wb'))
else:
    lda = pickle.load(open(LDA_MODEL, 'rb'))
    
pca = PCA(n_components=2) 
    
book_vectors = []
titles = []
for title in books:
    vector = np.zeros(50)
    book = lda.model[dictionary.doc2bow(books[title]['book_tokens'])]
    for pair in book:
        vector[pair[0]] = pair[1]
    titles.append(title)
    book_vectors.append(vector)

book_matrix = np.array(book_vectors)
pca_books = np.array([book for book in pca.fit_transform(book_matrix)])

x, y = zip(*pca_books)

# knn = KNeighborsClassifier(n_neighbors=5)
# knn.fit(pca_books, np.zeros(len(x)))
# neighbors = [book for book in knn.kneighbors(pca_books, n_neighbors=3)[1]]
# 
# neighbor_names = {} 
# for group in neighbors:
#     neighbor_names[titles[group[0]]] = [titles[j] for j in group[1:]]
#     
# for title in neighbor_names:
#     print(title, neighbor_names[title], '\n')
    
fig, ax = plt.subplots(1, 1, figsize=(30, 30))

ax.scatter(x, y)
for i in range(len(x)):
    ax.annotate(titles[i], (x[i],y[i])) 

plt.show()

# %% [markdown]
# ## LSI

# %%
from tqdm import tqdm_notebook as tqdm

# Get book texts split into chapters
preprocessor = PreProcessor(DICT, CORP, DELIM, RAW, TOKEN, 0)
dictionary, corpus, books = preprocessor.get_library_info()

if not isfile(LSI_MODEL):
    lsi = Library(dictionary, corpus, num_topics = 50, chunksize=10, model_type = 'LSI')
    for title in tqdm(books):
        lsi.add_book(books[title])

    pickle.dump(lsi, open(LSI_MODEL, 'wb'))
else:
    lsi = pickle.load(open(LSI_MODEL, 'rb'))
    
    
pca = PCA(n_components=2) 
    
book_vectors = []
titles = []
for title in books:
    vector = np.zeros(50)
    book = lsi.model[dictionary.doc2bow(books[title]['book_tokens'])]
    for pair in book:
        vector[pair[0]] = pair[1]
    titles.append(title)
    book_vectors.append(vector)

book_matrix = np.array(book_vectors)
pca_books = np.array([book for book in pca.fit_transform(book_matrix)])

x, y = zip(*pca_books)

# knn = KNeighborsClassifier(n_neighbors=5)
# knn.fit(pca_books, np.zeros(len(x)))
# neighbors = [book for book in knn.kneighbors(pca_books, n_neighbors=3)[1]]
# 
# neighbor_names = {} 
# for group in neighbors:
#     neighbor_names[titles[group[0]]] = [titles[j] for j in group[1:]]
#     
# for title in neighbor_names:
#     print(title, neighbor_names[title], '\n')

fig, ax = plt.subplots(1, 1, figsize=(30, 30))

ax.scatter(x, y)
for i in range(len(x)):
    ax.annotate(titles[i], (x[i],y[i])) 

plt.show()

# %% [markdown]
# ## Method

# %%
from topic_model import TopicModel

preprocessor = PreProcessor(DICT, CORP, DELIM, RAW, TOKEN, 0)
dictionary, corpus, books = preprocessor.get_library_info()

books = [(book, books[book]['book_tokens']) for book in books]
titles, books = zip(*books)

tm = TopicModel()
tm.add_documents(books)
y_axes = tm.gen_y_axes(1000, 25)
topic_freqs, book_topics = tm.calc_topics(books, y_axes)

sorted_topics = [(topic, topic_freqs[topic]) for topic in topic_freqs]
sorted_topics = sorted(sorted_topics, key=lambda x: x[1], reverse=True)[:50]

book_vectors = []
for book_index in range(len(book_topics)):
    book_vector = np.zeros(len(sorted_topics))

    for topic_index in range(len(sorted_topics)):
        topic = sorted_topics[topic_index][0]

        if topic in book_topics[book_index]:
            book_vector[topic_index] = np.average(book_topics[book_index][topic])

    book_vector_total = np.sum(book_vector)
    book_vector = [point/book_vector_total for point in book_vector]
    book_vectors.append(book_vector)
    
book_matrix = np.array(book_vectors)
pca_books = np.array([book for book in pca.fit_transform(book_matrix)])

x, y = zip(*pca_books)

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(pca_books, np.zeros(len(x)))
neighbors = [book for book in knn.kneighbors(pca_books, n_neighbors=5)[1]]

neighbor_names = {} 
for group in neighbors:
    neighbor_names[titles[group[0]]] = [titles[j] for j in group[1:]]
    
for title in neighbor_names:
    print(title, neighbor_names[title], '\n')

# fig, ax = plt.subplots(1, 1, figsize=(30, 30))
# 
# ax.scatter(x, y)
# for i in range(len(x)):
#     ax.annotate(titles[i], (x[i],y[i])) 
# 
# plt.show()
# Out:
# Adding Documents to Model: 100%|██████████| 37/37 [00:03<00:00, 11.11it/s]
# Generating Y Axes: 100%|██████████| 1000/1000 [01:03<00:00, 15.81it/s]
# Calculating Average Distances: 100%|██████████| 37/37 [01:30<00:00,  2.44s/it]
# Extracting Topics: 100%|██████████| 1000/1000 [00:00<00:00, 8710.13it/s]
# Adventures of Huckleberry Finn ['Sense and Sensibility', 'Wuthering Heights', 'Kidnapped', 'Pride and Prejudice']
#
# Alices Adventures in Wonderland ['Heart of Darkness', 'The Jungle', 'The Life and Adventures of Robinson Crusoe', 'Ethan Frome']
#
# Anna Karenina ['Treasure Island', 'The Wonderful Wizard of Oz', 'The Picture of Dorian Gray', 'War and Peace']
#
# Anthem ['The Three Musketeers', 'The Time Machine', 'Frankenstein', 'The Scarlett Letter']
#
# A Tale of Two Cities ['Oliver Twist', 'War and Peace', 'Great Expectations', 'The Brothers Karamazov']
#
# Captains Courageous ['Gullivers Travels', 'White Fang', 'Les Miserables', 'Phantom of the Opera']
#
# Crime and Punishment ['Dracula', 'Tarzan of the Apes', 'Frankenstein', 'The Scarlett Letter']
#
# Dracula ['Crime and Punishment', 'Tarzan of the Apes', 'Frankenstein', 'The Scarlett Letter']
#
# Ethan Frome ['The Adventures of Tom Sawyer', 'The Life and Adventures of Robinson Crusoe', 'White Fang', 'Alices Adventures in Wonderland']
#
# Frankenstein ['Crime and Punishment', 'Dracula', 'Tarzan of the Apes', 'The Scarlett Letter']
#
# Great Expectations ['The Brothers Karamazov', 'Oliver Twist', 'A Tale of Two Cities', 'War and Peace']
#
# Gullivers Travels ['Captains Courageous', 'White Fang', 'Les Miserables', 'Phantom of the Opera']
#
# Heart of Darkness ['Alices Adventures in Wonderland', 'The Jungle', 'The Life and Adventures of Robinson Crusoe', 'Ethan Frome']
#
# Kidnapped ['Adventures of Huckleberry Finn', 'Sense and Sensibility', 'Wuthering Heights', 'Pride and Prejudice']
#
# Les Miserables ['Phantom of the Opera', 'Treasure Island', 'War and Peace', 'A Tale of Two Cities']
#
# Oliver Twist ['A Tale of Two Cities', 'Great Expectations', 'War and Peace', 'The Brothers Karamazov']
#
# Phantom of the Opera ['Les Miserables', 'Treasure Island', 'Anna Karenina', 'Wuthering Heights']
#
# Pride and Prejudice ['The Wonderful Wizard of Oz', 'Anna Karenina', 'The Adventures of Sherlock Holmes', 'The Picture of Dorian Gray']
#
# Sense and Sensibility ['Wuthering Heights', 'Adventures of Huckleberry Finn', 'Treasure Island', 'Anna Karenina']
#
# Tarzan of the Apes ['Crime and Punishment', 'Dracula', 'The Scarlett Letter', 'Frankenstein']
#
# The Adventures of Sherlock Holmes ['The Wonderful Wizard of Oz', 'The Picture of Dorian Gray', 'War and Peace', 'A Tale of Two Cities']
#
# The Adventures of Tom Sawyer ['White Fang', 'Ethan Frome', 'The Count of Monte Cristo', 'Captains Courageous']
#
# The Brothers Karamazov ['Great Expectations', 'Oliver Twist', 'A Tale of Two Cities', 'War and Peace']
#
# The Call of the Wild ['The War of the Worlds', 'Heart of Darkness', 'The Life and Adventures of Robinson Crusoe', 'The Jungle']
#
# The Count of Monte Cristo ['The Brothers Karamazov', 'White Fang', 'Great Expectations', 'Oliver Twist']
#
# The Jungle ['Alices Adventures in Wonderland', 'Heart of Darkness', 'The Life and Adventures of Robinson Crusoe', 'Ethan Frome']
#
# The Life and Adventures of Robinson Crusoe ['Heart of Darkness', 'Alices Adventures in Wonderland', 'Ethan Frome', 'The Jungle']
#
# The Picture of Dorian Gray ['The Wonderful Wizard of Oz', 'War and Peace', 'A Tale of Two Cities', 'The Adventures of Sherlock Holmes']
#
# The Scarlett Letter ['Tarzan of the Apes', 'Crime and Punishment', 'Dracula', 'Frankenstein']
#
# The Three Musketeers ['The Time Machine', 'The Jungle', 'Anthem', 'Heart of Darkness']
#
# The Time Machine ['The Three Musketeers', 'The Jungle', 'Heart of Darkness', 'Alices Adventures in Wonderland']
#
# The War of the Worlds ['The Call of the Wild', 'Heart of Darkness', 'The Life and Adventures of Robinson Crusoe', 'Alices Adventures in Wonderland']
#
# The Wonderful Wizard of Oz ['The Picture of Dorian Gray', 'Anna Karenina', 'The Adventures of Sherlock Holmes', 'War and Peace']
#
# Treasure Island ['Anna Karenina', 'The Wonderful Wizard of Oz', 'The Picture of Dorian Gray', 'War and Peace']
#
# War and Peace ['A Tale of Two Cities', 'The Picture of Dorian Gray', 'Oliver Twist', 'Great Expectations']
#
# White Fang ['The Adventures of Tom Sawyer', 'The Count of Monte Cristo', 'Captains Courageous', 'The Brothers Karamazov']
#
# Wuthering Heights ['Sense and Sensibility', 'Treasure Island', 'Adventures of Huckleberry Finn', 'Anna Karenina']
